# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# Fun fact: Octopuses have three hearts—two pump blood to the gills, and the third pumps it to the rest of the body.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# A sealed box contains 12 coins that are visually identical, except that one coin is counterfeit: it is either heavier or lighter than the others, but you do not know which. You have a balance scale and are allowed exactly three weighings. What is the most information you can guarantee from the three weighings, and what exact procedure will always identify the counterfeit coin and determine whether it is heavier or lighter?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'A sealed box contains 12 coins that are visually identical, except that one coin is counterfeit: it is either heavier or lighter than the others, but you do not know which. You have a balance scale and are allowed exactly three weighings. What is the most information you can guarantee from the three weighings, and what exact procedure will always identify the counterfeit coin and determine whether it is heavier or lighter?'}]

# %%
# Ask the model to answer the hard question

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# With 3 weighings on a balance scale, you can guarantee at most
#
# \[
# 3^3 = 27
# \]
#
# distinct outcomes, because each weighing has 3 possible results: left heavy, right heavy, or balance.
#
# To identify the counterfeit among 12 coins, and also determine whether it is heavy or light, there are
#
# \[
# 12 \times 2 = 24
# \]
#
# possible cases. Since \(27 \ge 24\), it is possible in principle, and in fact there is a standard 3-weighing strategy that always works.
#
# ## Guaranteed information
# You can always determine:
#
# - which one of the 12 coins is counterfeit, and
# - whether it is heavier or lighter than a genuine coin.
#
# ---
#
# # Exact procedure
#
# Label the coins \(1,2,\dots,12\).
#
# ## Weighing 1
# Weigh:
#
# - Left pan: coins \(1,2,3,4\)
# - Right pan: coins \(5,6,7,8\)
#
# Coins \(9,10,11,12\) are left off the scale.
#
# There are 3 cases.
#
# ---
#
# ## Case 1: Weighing 1 balances
# Then coins \(1\) through \(8\) are genuine, so the counterfeit is among \(9,10,11,12\).
#
# ### Weighing 2
# Weigh:
#
# - Left pan: coins \(9,10\)
# - Right pan: coins \(11,1\)  (coin 1 is known genuine)
#
# Now:
#
# - **If it balances:** coin 12 is counterfeit.
#   - **Weighing 3:** weigh coin 12 against coin 1.
#     - If 12 is heavier, it is heavy.
#     - If 12 is lighter, it is light.
#
# - **If left side is heavier:** then either coin 9 or 10 is heavy, or coin 11 is light.
#   - **Weighing 3:** weigh coin 9 against coin 10.
#     - If one is heavier, that one is the counterfeit and it is heavy.
#     - If they balance, then coin 11 is counterfeit and it is light.
#
# - **If right side is heavier:** then either coin 11 is heavy, or coin 9 or 10 is light.
#   - **Weighing 3:** weigh coin 9 against coin 10.
#     - If one is lighter, that one is the counterfeit and it is light.
#     - If they balance, then coin 11 is counterfeit and it is heavy.
#
# ---
#
# ## Case 2: Weighing 1 left side is heavier
# Then among coins \(1,2,3,4,5,6,7,8\), either:
#
# - one of \(1,2,3,4\) is heavy, or
# - one of \(5,6,7,8\) is light.
#
# Coins \(9\)–\(12\) are genuine and can be used as references.
#
# ### Weighing 2
# Weigh:
#
# - Left pan: coins \(1,2,5\)
# - Right pan: coins \(3,6,9\)  (coin 9 is genuine)
#
# Now:
#
# - **If left side is heavier:** possible counterfeit cases are:
#   - coin 1 heavy
#   - coin 2 heavy
#   - coin 6 light
#
#   **Weighing 3:** weigh coin 1 against coin 2.
#   - If one is heavier, that coin is counterfeit and heavy.
#   - If they balance, coin 6 is counterfeit and light.
#
# - **If right side is heavier:** possible counterfeit cases are:
#   - coin 3 heavy
#   - coin 5 light
#
#   **Weighing 3:** weigh coin 3 against coin 9.
#   - If coin 3 is heavier, it is counterfeit and heavy.
#   - If they balance, coin 5 is counterfeit and light.
#
# - **If it balances:** possible counterfeit cases are:
#   - coin 4 heavy
#   - coin 7 light
#   - coin 8 light
#
#   **Weighing 3:** weigh coin 7 against coin 8.
#   - If one is lighter, that one is counterfeit and light.
#   - If they balance, coin 4 is counterfeit and heavy.
#
# ---
#
# ## Case 3: Weighing 1 right side is heavier
# This is symmetric to Case 2.
#
# Then among coins \(1,2,3,4,5,6,7,8\), either:
#
# - one of \(5,6,7,8\) is heavy, or
# - one of \(1,2,3,4\) is light.
#
# ### Weighing 2
# Weigh:
#
# - Left pan: coins \(5,6,1\)
# - Right pan: coins \(7,2,9\)  (coin 9 is genuine)
#
# Now:
#
# - **If left side is heavier:** possible counterfeit cases are:
#   - coin 5 heavy
#   - coin 6 heavy
#   - coin 2 light
#
#   **Weighing 3:** weigh coin 5 against coin 6.
#   - If one is heavier, that one is counterfeit and heavy.
#   - If they balance, coin 2 is counterfeit and light.
#
# - **If right side is heavier:** possible counterfeit cases are:
#   - coin 7 heavy
#   - coin 1 light
#
#   **Weighing 3:** weigh coin 7 against coin 9.
#   - If coin 7 is heavier, it is counterfeit and heavy.
#   - If they balance, coin 1 is counterfeit and light.
#
# - **If it balances:** possible counterfeit cases are:
#   - coin 8 heavy
#   - coin 3 light
#   - coin 4 light
#
#   **Weighing 3:** weigh coin 3 against coin 4.
#   - If one is lighter, that one is counterfeit and light.
#   - If they balance, coin 8 is counterfeit and heavy.
#
# ---
#
# # Summary
# - Three weighings can distinguish among up to \(27\) outcomes.
# - Since 12 coins with heavy/light ambiguity gives 24 cases, it is possible.
# - The above decision tree always identifies:
#   1. the counterfeit coin, and
#   2. whether it is heavier or lighter.
#
# If you want, I can also give this as a compact decision tree or a table for easier memorization.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# With 3 weighings on a balance scale, you can guarantee at most
#
# \[
# 3^3 = 27
# \]
#
# distinct outcomes, because each weighing has 3 possible results: left heavy, right heavy, or balance.
#
# To identify the counterfeit among 12 coins, and also determine whether it is heavy or light, there are
#
# \[
# 12 \times 2 = 24
# \]
#
# possible cases. Since \(27 \ge 24\), it is possible in principle, and in fact there is a standard 3-weighing strategy that always works.
#
# ## Guaranteed information
# You can always determine:
#
# - which one of the 12 coins is counterfeit, and
# - whether it is heavier or lighter than a genuine coin.
#
# ---
#
# # Exact procedure
#
# Label the coins \(1,2,\dots,12\).
#
# ## Weighing 1
# Weigh:
#
# - Left pan: coins \(1,2,3,4\)
# - Right pan: coins \(5,6,7,8\)
#
# Coins \(9,10,11,12\) are left off the scale.
#
# There are 3 cases.
#
# ---
#
# ## Case 1: Weighing 1 balances
# Then coins \(1\) through \(8\) are genuine, so the counterfeit is among \(9,10,11,12\).
#
# ### Weighing 2
# Weigh:
#
# - Left pan: coins \(9,10\)
# - Right pan: coins \(11,1\)  (coin 1 is known genuine)
#
# Now:
#
# - **If it balances:** coin 12 is counterfeit.
#   - **Weighing 3:** weigh coin 12 against coin 1.
#     - If 12 is heavier, it is heavy.
#     - If 12 is lighter, it is light.
#
# - **If left side is heavier:** then either coin 9 or 10 is heavy, or coin 11 is light.
#   - **Weighing 3:** weigh coin 9 against coin 10.
#     - If one is heavier, that one is the counterfeit and it is heavy.
#     - If they balance, then coin 11 is counterfeit and it is light.
#
# - **If right side is heavier:** then either coin 11 is heavy, or coin 9 or 10 is light.
#   - **Weighing 3:** weigh coin 9 against coin 10.
#     - If one is lighter, that one is the counterfeit and it is light.
#     - If they balance, then coin 11 is counterfeit and it is heavy.
#
# ---
#
# ## Case 2: Weighing 1 left side is heavier
# Then among coins \(1,2,3,4,5,6,7,8\), either:
#
# - one of \(1,2,3,4\) is heavy, or
# - one of \(5,6,7,8\) is light.
#
# Coins \(9\)–\(12\) are genuine and can be used as references.
#
# ### Weighing 2
# Weigh:
#
# - Left pan: coins \(1,2,5\)
# - Right pan: coins \(3,6,9\)  (coin 9 is genuine)
#
# Now:
#
# - **If left side is heavier:** possible counterfeit cases are:
#   - coin 1 heavy
#   - coin 2 heavy
#   - coin 6 light
#
#   **Weighing 3:** weigh coin 1 against coin 2.
#   - If one is heavier, that coin is counterfeit and heavy.
#   - If they balance, coin 6 is counterfeit and light.
#
# - **If right side is heavier:** possible counterfeit cases are:
#   - coin 3 heavy
#   - coin 5 light
#
#   **Weighing 3:** weigh coin 3 against coin 9.
#   - If coin 3 is heavier, it is counterfeit and heavy.
#   - If they balance, coin 5 is counterfeit and light.
#
# - **If it balances:** possible counterfeit cases are:
#   - coin 4 heavy
#   - coin 7 light
#   - coin 8 light
#
#   **Weighing 3:** weigh coin 7 against coin 8.
#   - If one is lighter, that one is counterfeit and light.
#   - If they balance, coin 4 is counterfeit and heavy.
#
# ---
#
# ## Case 3: Weighing 1 right side is heavier
# This is symmetric to Case 2.
#
# Then among coins \(1,2,3,4,5,6,7,8\), either:
#
# - one of \(5,6,7,8\) is heavy, or
# - one of \(1,2,3,4\) is light.
#
# ### Weighing 2
# Weigh:
#
# - Left pan: coins \(5,6,1\)
# - Right pan: coins \(7,2,9\)  (coin 9 is genuine)
#
# Now:
#
# - **If left side is heavier:** possible counterfeit cases are:
#   - coin 5 heavy
#   - coin 6 heavy
#   - coin 2 light
#
#   **Weighing 3:** weigh coin 5 against coin 6.
#   - If one is heavier, that one is counterfeit and heavy.
#   - If they balance, coin 2 is counterfeit and light.
#
# - **If right side is heavier:** possible counterfeit cases are:
#   - coin 7 heavy
#   - coin 1 light
#
#   **Weighing 3:** weigh coin 7 against coin 9.
#   - If coin 7 is heavier, it is counterfeit and heavy.
#   - If they balance, coin 1 is counterfeit and light.
#
# - **If it balances:** possible counterfeit cases are:
#   - coin 8 heavy
#   - coin 3 light
#   - coin 4 light
#
#   **Weighing 3:** weigh coin 3 against coin 4.
#   - If one is lighter, that one is counterfeit and light.
#   - If they balance, coin 8 is counterfeit and heavy.
#
# ---
#
# # Summary
# - Three weighings can distinguish among up to \(27\) outcomes.
# - Since 12 coins with heavy/light ambiguity gives 24 cases, it is possible.
# - The above decision tree always identifies:
#   1. the counterfeit coin, and
#   2. whether it is heavier or lighter.
#
# If you want, I can also give this as a compact decision tree or a table for easier memorization.

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# A sealed box contains 12 coins that are visually identical, except that one coin is counterfeit: it is either heavier or lighter than the others, but you do not know which. You have a balance scale and are allowed exactly three weighings. What is the most information you can guarantee from the three weighings, and what exact procedure will always identify the counterfeit coin and determine whether it is heavier or lighter?
#
# And here is a possible answer that might be correct or incorrect:
# With 3 weighings on a balance scale, you can guarantee at most
#
# \[
# 3^3 = 27
# \]
#
# distinct outcomes, because each weighing has 3 possible results: left heavy, right heavy, or balance.
#
# To identify the counterfeit among 12 coins, and also determine whether it is heavy or light, there are
#
# \[
# 12 \times 2 = 24
# \]
#
# possible cases. Since \(27 \ge 24\), it is possible in principle, and in fact there is a standard 3-weighing strategy that always works.
#
# ## Guaranteed information
# You can always determine:
#
# - which one of the 12 coins is counterfeit, and
# - whether it is heavier or lighter than a genuine coin.
#
# ---
#
# # Exact procedure
#
# Label the coins \(1,2,\dots,12\).
#
# ## Weighing 1
# Weigh:
#
# - Left pan: coins \(1,2,3,4\)
# - Right pan: coins \(5,6,7,8\)
#
# Coins \(9,10,11,12\) are left off the scale.
#
# There are 3 cases.
#
# ---
#
# ## Case 1: Weighing 1 balances
# Then coins \(1\) through \(8\) are genuine, so the counterfeit is among \(9,10,11,12\).
#
# ### Weighing 2
# Weigh:
#
# - Left pan: coins \(9,10\)
# - Right pan: coins \(11,1\)  (coin 1 is known genuine)
#
# Now:
#
# - **If it balances:** coin 12 is counterfeit.
#   - **Weighing 3:** weigh coin 12 against coin 1.
#     - If 12 is heavier, it is heavy.
#     - If 12 is lighter, it is light.
#
# - **If left side is heavier:** then either coin 9 or 10 is heavy, or coin 11 is light.
#   - **Weighing 3:** weigh coin 9 against coin 10.
#     - If one is heavier, that one is the counterfeit and it is heavy.
#     - If they balance, then coin 11 is counterfeit and it is light.
#
# - **If right side is heavier:** then either coin 11 is heavy, or coin 9 or 10 is light.
#   - **Weighing 3:** weigh coin 9 against coin 10.
#     - If one is lighter, that one is the counterfeit and it is light.
#     - If they balance, then coin 11 is counterfeit and it is heavy.
#
# ---
#
# ## Case 2: Weighing 1 left side is heavier
# Then among coins \(1,2,3,4,5,6,7,8\), either:
#
# - one of \(1,2,3,4\) is heavy, or
# - one of \(5,6,7,8\) is light.
#
# Coins \(9\)–\(12\) are genuine and can be used as references.
#
# ### Weighing 2
# Weigh:
#
# - Left pan: coins \(1,2,5\)
# - Right pan: coins \(3,6,9\)  (coin 9 is genuine)
#
# Now:
#
# - **If left side is heavier:** possible counterfeit cases are:
#   - coin 1 heavy
#   - coin 2 heavy
#   - coin 6 light
#
#   **Weighing 3:** weigh coin 1 against coin 2.
#   - If one is heavier, that coin is counterfeit and heavy.
#   - If they balance, coin 6 is counterfeit and light.
#
# - **If right side is heavier:** possible counterfeit cases are:
#   - coin 3 heavy
#   - coin 5 light
#
#   **Weighing 3:** weigh coin 3 against coin 9.
#   - If coin 3 is heavier, it is counterfeit and heavy.
#   - If they balance, coin 5 is counterfeit and light.
#
# - **If it balances:** possible counterfeit cases are:
#   - coin 4 heavy
#   - coin 7 light
#   - coin 8 light
#
#   **Weighing 3:** weigh coin 7 against coin 8.
#   - If one is lighter, that one is counterfeit and light.
#   - If they balance, coin 4 is counterfeit and heavy.
#
# ---
#
# ## Case 3: Weighing 1 right side is heavier
# This is symmetric to Case 2.
#
# Then among coins \(1,2,3,4,5,6,7,8\), either:
#
# - one of \(5,6,7,8\) is heavy, or
# - one of \(1,2,3,4\) is light.
#
# ### Weighing 2
# Weigh:
#
# - Left pan: coins \(5,6,1\)
# - Right pan: coins \(7,2,9\)  (coin 9 is genuine)
#
# Now:
#
# - **If left side is heavier:** possible counterfeit cases are:
#   - coin 5 heavy
#   - coin 6 heavy
#   - coin 2 light
#
#   **Weighing 3:** weigh coin 5 against coin 6.
#   - If one is heavier, that one is counterfeit and heavy.
#   - If they balance, coin 2 is counterfeit and light.
#
# - **If right side is heavier:** possible counterfeit cases are:
#   - coin 7 heavy
#   - coin 1 light
#
#   **Weighing 3:** weigh coin 7 against coin 9.
#   - If coin 7 is heavier, it is counterfeit and heavy.
#   - If they balance, coin 1 is counterfeit and light.
#
# - **If it balances:** possible counterfeit cases are:
#   - coin 8 heavy
#   - coin 3 light
#   - coin 4 light
#
#   **Weighing 3:** weigh coin 3 against coin 4.
#   - If one is lighter, that one is counterfeit and light.
#   - If they balance, coin 8 is counterfeit and heavy.
#
# ---
#
# # Summary
# - Three weighings can distinguish among up to \(27\) outcomes.
# - Since 12 coins with heavy/light ambiguity gives 24 cases, it is possible.
# - The above decision tree always identifies:
#   1. the counterfeit coin, and
#   2. whether it is heavier or lighter.
#
# If you want, I can also give this as a compact decision tree or a table for easier memorization.
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model="gpt-5.4", messages=messages)
print(response.choices[0].message.content)

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:



messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic AI opportunity."}]

# Then make the first call:

response = openai.chat.completions.create(model="gpt-5.4", messages=messages)

# Then read the business idea:

business_area = response.choices[0].message.content

print(business_area)

# And repeat! In the next message, include the business area within the message
# Out:
# One strong business area to explore for an Agentic AI opportunity is **accounts payable and invoice operations**.
#
# Why this is a good candidate:
# - **High-volume, repetitive work**: receiving invoices, extracting data, matching to purchase orders, routing exceptions, following up on approvals.
# - **Clear workflows**: the process usually follows defined rules, which makes it easier for an AI agent to act autonomously within guardrails.
# - **Painful bottlenecks**: delays, manual errors, duplicate payments, and exception handling are common.
# - **Measurable ROI**: you can track time saved, faster cycle times, reduced errors, and improved cash-flow management.
# - **Multi-step decisioning**: this is where agentic AI is more valuable than simple automation, because it can interpret documents, decide next actions, request missing information, and escalate edge cases.
#
# What an Agentic AI solution could do:
# - Monitor incoming invoice channels
# - Extract and validate invoice data
# - Match invoices to POs and receipts
# - Route exceptions to the right approver
# - Follow up automatically on stalled approvals
# - Flag duplicate or suspicious invoices
# - Prepare payment recommendations
# - Maintain a full audit trail
#
# Why it’s especially attractive:
# - It sits between simple RPA and full human judgment, which is ideal for agentic systems.
# - Companies across many industries have the same problem.
# - It can often be deployed incrementally rather than requiring a full transformation.
#
# If you want, I can also suggest:
# 1. **3 more business areas** worth exploring, or
# 2. a **specific Agentic AI product idea** in accounts payable.

# %%
message = f"""
Present a pain-point in my selected industry - something challenging that might be ripe for an Agentic solution. The selected industry:
{business_area}
"""

messages = [{"role": "user", "content": message}]

response = openai.chat.completions.create(model="gpt-5.4", messages=messages)

pain_point = response.choices[0].message.content

print(pain_point)
# Out:
# A strong pain point in **accounts payable and invoice operations** is:
#
# ## Exception handling in invoice approval workflows
#
# Most AP teams can automate the “happy path,” but a large share of invoices fall out of that path because of small issues like:
#
# - missing PO numbers
# - mismatched quantities or prices
# - missing receipts
# - unclear vendor details
# - invoices sent to the wrong entity or approver
# - approvals that stall for days or weeks
#
# ### Why this is so painful
# These exceptions usually require humans to:
# - investigate across ERP, email, and procurement systems
# - contact vendors or internal stakeholders
# - decide who should approve or resolve the issue
# - keep following up until the invoice moves again
#
# That creates:
# - long payment cycle times
# - missed early-payment discounts
# - late-payment penalties
# - frustrated vendors
# - heavy manual workload for AP staff
# - poor visibility into where invoices are stuck
#
# ### Why it’s ripe for an Agentic solution
# This is a good fit for agentic AI because resolving exceptions is not just one task—it’s a sequence of decisions and actions. An agent could:
#
# - detect the reason an invoice failed straight-through processing
# - gather context from ERP, PO, receipt, and vendor records
# - determine the likely next best action
# - message the correct approver or buyer
# - request missing information from vendors
# - follow up automatically if no response arrives
# - escalate based on urgency, amount, or due date
# - keep a full audit trail of every step taken
#
# ### Why this stands out as an opportunity
# Unlike basic OCR or RPA, exception handling involves judgment, coordination, and persistence—exactly where agentic systems can add value. It’s also highly measurable: fewer blocked invoices, faster approvals, lower manual effort, and better on-time payment performance.
#
# If you want, I can next turn this into:
# - a **problem statement for a pitch deck**, or
# - a **specific Agentic AI solution concept** for AP exception handling.

# %%
message = f"""
Propose the Agentic AI solution for my pain-point:
{pain_point}
"""

messages = [{"role": "user", "content": message}]

response = openai.chat.completions.create(model="gpt-5.4", messages=messages)

solution = response.choices[0].message.content

print(solution)
# Out:
# Here’s a strong **Agentic AI solution concept** for your AP pain point:
#
# # Agentic AI Solution: AP Exception Resolution Agent
#
# ## 1. Solution overview
# An **AP Exception Resolution Agent** is an AI-driven workflow agent that autonomously manages invoice exceptions from detection through resolution.
#
# Instead of only flagging problems, the agent:
# - identifies why an invoice is blocked
# - gathers evidence from connected systems
# - determines the best next step
# - communicates with the right people
# - follows up until resolution
# - escalates when needed
# - logs every action for auditability
#
# It acts like a digital AP analyst focused specifically on getting “stuck” invoices moving again.
#
# ---
#
# ## 2. Core use cases it handles
# The agent would resolve common AP exceptions such as:
#
# - **Missing PO number**
#   - checks vendor history, email context, and ERP records
#   - suggests or identifies likely PO
#   - asks vendor or buyer for confirmation if needed
#
# - **2-way / 3-way match failures**
#   - compares invoice, PO, and receipt data
#   - identifies whether issue is price variance, quantity variance, or missing receipt
#   - routes to receiving team, buyer, or AP based on cause
#
# - **Missing goods receipt**
#   - detects whether goods were likely received but not recorded
#   - prompts requestor/warehouse to create receipt
#   - follows up automatically until completed
#
# - **Vendor master issues**
#   - detects name/address/entity/bank/tax ID mismatch
#   - gathers vendor master data and prior invoice patterns
#   - routes to vendor management or requests documentation from supplier
#
# - **Wrong legal entity or approver**
#   - uses invoice metadata, supplier, cost center, and historical approvals
#   - recommends correct entity/approver
#   - reroutes automatically where policy allows
#
# - **Stalled approvals**
#   - monitors aging
#   - nudges approvers with context-aware reminders
#   - escalates based on SLA, invoice amount, discount window, or due date
#
# ---
#
# ## 3. How the agent works
# ### Step 1: Detect exception
# The agent listens to invoice workflow events from ERP/AP automation platforms and detects when an invoice leaves straight-through processing.
#
# Example triggers:
# - “PO missing”
# - “Match failed”
# - “Approval overdue”
# - “Vendor record mismatch”
#
# ### Step 2: Diagnose root cause
# The agent investigates across systems:
# - ERP
# - procurement platform
# - goods receipt / inventory system
# - vendor master
# - email inbox
# - workflow/approval logs
# - contract repository if relevant
#
# It classifies:
# - exact exception type
# - probable cause
# - urgency level
# - responsible party
# - recommended next action
#
# ### Step 3: Plan next-best action
# The agent chooses the optimal workflow step based on rules + AI reasoning.
#
# Examples:
# - send clarification request to vendor
# - ask buyer to confirm price variance
# - request receipt posting from warehouse/requestor
# - reroute approval to correct manager
# - escalate to AP lead for policy exception
#
# ### Step 4: Execute actions
# The agent takes action directly:
# - sends email or Teams/Slack messages
# - updates workflow status
# - assigns tasks
# - adds supporting notes
# - schedules follow-ups
# - triggers escalations
#
# ### Step 5: Persist until resolved
# This is where it becomes truly agentic.
#
# The agent does not stop after one alert. It:
# - waits for responses
# - interprets replies
# - takes the next action
# - reminds stakeholders
# - escalates if deadlines pass
# - closes the loop when invoice is approved, corrected, or rejected
#
# ### Step 6: Maintain audit trail
# Every decision and action is recorded:
# - what issue was detected
# - what evidence was reviewed
# - what action was taken
# - who was contacted
# - why escalation occurred
# - final resolution
#
# This is critical for finance controls and compliance.
#
# ---
#
# ## 4. Key agent capabilities
# ## A. Context gathering
# The agent pulls and synthesizes:
# - invoice header and line data
# - PO details
# - receipt status
# - vendor history
# - prior similar exceptions
# - approver hierarchy
# - payment terms and due dates
# - communication history
#
# ## B. Decision intelligence
# The agent can decide:
# - who owns the issue
# - whether issue is likely data error vs policy exception
# - whether to request information internally or externally
# - whether to escalate now or wait
# - whether an exception is low-risk and eligible for auto-resolution under policy
#
# ## C. Autonomous communication
# The agent drafts and sends messages like:
# - “Please confirm receipt against PO 45821 for invoice INV-8821”
# - “Price variance of 4.2% exceeds tolerance. Can buyer approve?”
# - “Vendor invoice appears submitted to wrong legal entity. Please reissue to XYZ Ltd.”
#
# These messages can be tailored by stakeholder type and urgency.
#
# ## D. Follow-up orchestration
# The agent manages reminders and escalations:
# - reminder after 2 business days
# - escalate after 5 days
# - fast-track if discount deadline is near
# - notify AP manager if invoice exceeds threshold amount
#
# ## E. Explainability
# The agent provides a concise reason:
# - “Invoice blocked because quantity billed (100) exceeds received quantity (85). Requested receiving confirmation from warehouse manager.”
# - “Approver reassigned based on cost center owner history and approval matrix.”
#
# ---
#
# ## 5. Example workflow
# ### Scenario: Invoice blocked due to missing receipt
# 1. Invoice arrives and matches PO, but no goods receipt exists.
# 2. Agent checks:
#    - PO owner
#    - requestor
#    - delivery status
#    - prior receipt patterns
#    - shipping/delivery references if available
# 3. Agent determines likely owner is warehouse receiver or department requestor.
# 4. Agent sends message:
#    - “Invoice 10455 from Vendor A is blocked because PO 77631 has no recorded receipt. Please confirm receipt or advise discrepancy.”
# 5. If no response in 48 hours:
#    - sends reminder
# 6. If invoice due date is approaching:
#    - escalates to department manager
# 7. Once receipt is posted:
#    - agent rechecks match
#    - resubmits invoice for approval
# 8. Audit log records full timeline.
#
# ---
#
# ## 6. Business value
# This solution would improve:
#
# - **Invoice cycle time**
#   - faster exception resolution
# - **Touchless processing rate**
#   - more invoices returned to flow with minimal AP effort
# - **AP productivity**
#   - fewer manual chases and investigations
# - **On-time payment performance**
#   - fewer late payments
# - **Discount capture**
#   - more early-payment discounts preserved
# - **Vendor experience**
#   - fewer unanswered supplier queries
# - **Operational visibility**
#   - real-time tracking of bottlenecks and aging exceptions
#
# ---
#
# ## 7. KPIs to measure success
# You can quantify impact with metrics such as:
#
# - % of invoices falling into exception
# - average exception resolution time
# - approval cycle time
# - % of stalled approvals auto-recovered
# - manual touches per exception
# - on-time payment rate
# - late fees avoided
# - early-payment discounts captured
# - AP staff hours saved
# - vendor inquiry volume
# - exception backlog aging
#
# ---
#
# ## 8. Why this is truly agentic, not just automation
# Traditional automation:
# - follows predefined rules
# - stops when data is missing
# - relies on humans to pick up the issue
#
# Agentic AI:
# - investigates ambiguity
# - chooses among multiple possible actions
# - communicates proactively
# - adapts based on responses
# - persists until an outcome is reached
#
# So the value is not just “flagging exceptions,” but **owning exception resolution end-to-end**.
#
# ---
#
# ## 9. Recommended system architecture
# A practical architecture would include:
#
# - **Event listener / workflow trigger**
#   - detects blocked invoices from ERP or AP platform
#
# - **Orchestration agent**
#   - manages case state and next actions
#
# - **Reasoning layer**
#   - classifies exception and recommends actions
#
# - **System connectors**
#   - ERP, procurement, vendor master, email, collaboration tools
#
# - **Communication agent**
#   - sends emails/messages and interprets responses
#
# - **Rules + policy engine**
#   - enforces approval matrix, tolerance thresholds, escalation rules
#
# - **Audit and monitoring layer**
#   - logs actions, provides dashboards, supports compliance review
#
# - **Human-in-the-loop controls**
#   - required for sensitive actions like overriding tolerances or vendor master changes
#
# ---
#
# ## 10. Safe deployment approach
# Start narrow and expand.
#
# ### Phase 1: Copilot mode
# - agent diagnoses exceptions
# - recommends actions to AP analyst
# - drafts emails and routing suggestions
#
# ### Phase 2: Semi-autonomous mode
# - agent sends reminders and gathers missing info automatically
# - humans approve higher-risk decisions
#
# ### Phase 3: Autonomous resolution for low-risk cases
# - reroute simple approvals
# - chase missing receipts
# - request standard vendor clarifications
# - auto-escalate by SLA rules
#
# This phased model reduces risk while proving ROI early.
#
# ---
#
# ## 11. Strong product positioning statement
# **“An AI agent for accounts payable that autonomously resolves invoice exceptions by investigating issues, coordinating with stakeholders, following up persistently, and moving invoices to payment faster.”**
#
# ---
#
# ## 12. Short pitch version
# **AP Exception Resolution Agent** helps finance teams eliminate the biggest bottleneck in invoice operations: stuck invoices. The agent detects why invoices fail, gathers context across ERP and procurement systems, contacts the right people, follows up automatically, and escalates when needed—reducing manual effort, shortening approval cycles, and improving on-time payment.
#
# If you want, I can next turn this into one of these:
# 1. a **1-slide pitch deck summary**,
# 2. a **detailed product requirements document (PRD)**, or
# 3. a **multi-agent architecture diagram and workflow**.
